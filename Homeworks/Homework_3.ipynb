# %% [markdown]
# <a href="https://colab.research.google.com/github/mbenejam/bme3053c/blob/main/Homework_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pulse oximetry is a non-invasive method used to measure the oxygen saturation (SpO2) level in the blood. The device measures the absorption of light at two wavelengths (usually red and infrared) to estimate SpO2. One of the challenges in pulse oximetry is identifying and analyzing peaks in the photoplethysmogram (PPG) signal, which corresponds to the heartbeats.
#
#
#
# You have a list of PPG signal values (simulated data) over time, sampled at regular intervals. Your task is to write a function that counts the number of peaks in the PPG signal using a for loop and range.
#
#
#
# Copy the code below into a python file or Colab notebook.
# Create a function that receives a list as an input argument and uses a for loop with range to iterate through the PPG signal values and identify peaks.
# A peak is a signal point where the value is greater than its immediate neighbors. Specifically, for a value at index i to be considered a peak, it must satisfy:
# ppg_signal[i] > ppg_signal[i - 1]
# ppg_signal[i] > ppg_signal[i + 1]
# Your function should count the total number of peaks and print that value.
# Call your function with ppg_signal as the input.
# Upload your script or notebook.
#
#
# import math
# import random
#
# ppg_signal = [1000 + 100 * math.sin(0.1 * x) + random.randint(-20, 20) for x in range(100)]

# %%
import math
import random

ppg_signal = [1000 + 100 * math.sin(0.1 * x) + random.randint(-20, 20) for x in range(100)]
peak_detected= False

def ppg_peak_detector(ppg_array):
  for i in range(2,len(ppg_array)-1,1):
    print(ppg_array[i])
    if ppg_signal[i] > ppg_signal[i - 1] and ppg_signal[i] > ppg_signal[i + 1]:
      peak_detected= True
      if peak_detected== True:
        print('peak detected', ppg_array[i])
        peak_detected= False

ppg_peak_detector(ppg_signal)
# Out:
# 1038.866933079506
# 1045.552020666134
# peak detected 1045.552020666134
# 1035.941834230865
# 1030.9425538604203
# 1040.4642473395036
# 1047.4217687237692
# 1060.7356090899523
# 1093.3326909627483
# peak detected 1093.3326909627483
# 1067.1470984807897
# 1093.1207360061435
# 1094.2039085967226
# 1114.3558185417194
# peak detected 1114.3558185417194
# 1083.544972998846
# 1096.7494986604054
# peak detected 1096.7494986604054
# 1086.9573603041506
# 1103.1664810452469
# 1106.3847630878195
# peak detected 1106.3847630878195
# 1078.6300087687414
# 1087.929742682568
# peak detected 1087.929742682568
# 1072.3209366648873
# 1098.849640381959
# peak detected 1098.849640381959
# 1093.570521217672
# 1051.546318055115
# 1073.8472144103957
# peak detected 1073.8472144103957
# 1038.5501371821465
# 1025.737988023383
# 1033.4988150155905
# peak detected 1033.4988150155905
# 1027.924932921398
# 1034.1120008059866
# peak detected 1034.1120008059866
# 1020.158066243329
# 982.162585657242
# 986.2254305856751
# 987.4458897973168
# peak detected 987.4458897973168
# 957.9216772310381
# 960.7479556705148
# 966.0163859091507
# peak detected 966.0163859091507
# 918.814210905728
# 915.2233840816026
# 938.3197504692072
# peak detected 938.3197504692072
# 920.172288893559
# 923.8424227586412
# peak detected 923.8424227586412
# 907.3834063250545
# 905.8397926110484
# 906.2469882334904
# peak detected 906.2469882334904
# 893.6308996366536
# 894.0076742435899
# peak detected 894.0076742435899
# 891.3835391164159
# 901.7547387375668
# 913.1075725336862
# 919.4185317672268
# peak detected 919.4185317672268
# 916.6545344279847
# 912.77325577761
# 912.7235512444013
# 929.4459674429609
# peak detected 929.4459674429609
# 924.8733362127679
# 936.9314457402362
# peak detected 936.9314457402362
# 933.5397820586244
# 965.6123335169764
# 983.0584501801075
# peak detected 983.0584501801075
# 974.7837495727905
# 1009.6910597182504
# peak detected 1009.6910597182504
# 995.6813900484351
# 1017.6549204850494
# 1032.5119988087815
# peak detected 1032.5119988087815
# 1027.154136351338
# 1052.4849920616598
# 1069.4113351138608
# peak detected 1069.4113351138608
# 1062.84397643882
# 1059.6986598718788
# 1090.8969040125876
# 1095.3667863849153
# peak detected 1095.3667863849153
# 1071.0436620628566
# 1091.8708095811626
# 1094.7999976774738
# 1106.7919672031487
# peak detected 1106.7919672031487
# 1102.8168233877
# 1081.8543345374605
# 1107.8941341839773
# peak detected 1107.8941341839773
# 1090.9358246623383
# 1095.9889810845086
# peak detected 1095.9889810845086
# 1088.0730556679773
# 1083.2171833756292
# 1091.459890808828
# peak detected 1091.459890808828
# 1085.848711262349
# 1071.4397097874114
# 1057.2969230082183
# 1059.4917192891762
# 1070.1020856457885
# peak detected 1070.1020856457885
# 1048.2118485241756
# 1027.9098362349353
# 1042.2889914100247
# peak detected 1042.2889914100247
# 994.4454423507061
# 1014.4775425453357
# peak detected 1014.4775425453357
# 976.4848879538191
# 1000.5673218777018
# peak detected 1000.5673218777018
# 952.8239373589056
# 976.3520870748072
# peak detected 976.3520870748072
